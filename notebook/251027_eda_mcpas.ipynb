# %%
import pandas as pd

df = pd.read_csv("../data/latest_251022/mcpas/McPAS-TCR.csv")
# Out:
# /tmp/ipykernel_331258/4192523333.py:3: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/latest_251022/mcpas/McPAS-TCR.csv")

# %%
df["CDR3.beta.aa"]
# Out:
# 0           ATSIRFTDTQYF
# 1         CAAAAASGAYEQYF
# 2        CAAADEEIGNQPQHF
# 3         CAAAGGPDTGELFF
# 4         CAAEDDTGGFKTIF
#               ...
# 40726     CASSPKRTRQLSIS
# 40727     CASSPTRPAARRLS
# 40728     CASSTRQLFTSVPP
# 40729     CASSTPPAARRLGP
# 40730     CASSAHRAGGLGRV
# Name: CDR3.beta.aa, Length: 40731, dtype: object

# %%
# 길이별 분포 히스토그램
import matplotlib.pyplot as plt
df['CDR3.beta.aa'].str.len().hist(bins=50)
plt.xlabel('Length')
plt.ylabel('Frequency')
plt.title('CDR3.beta.aa Length Distribution')
plt.show()
